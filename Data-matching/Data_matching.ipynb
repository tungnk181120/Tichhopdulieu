# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install strsimpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.2 MB/s
# Installing collected packages: strsimpy
# Successfully installed strsimpy-0.2.1

# %%
import pandas as pd
import numpy as np
import strsimpy
data_path = "/content/drive/MyDrive/Colab Notebooks/test_tichhop/All_data.csv"
data_df = pd.read_csv(data_path)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7745 entries, 0 to 7744
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7745 non-null   object
#  1   Hotel name         7745 non-null   object
#  2   Url                7745 non-null   object
#  3   Address            7745 non-null   object
#  4   Stars              7745 non-null   float64
#  5   Price              7745 non-null   int64
#  6   Rating             7745 non-null   float64
#  7   Number of reviews  7745 non-null   int64
#  8   Reviews            7745 non-null   object
#  9   Facilities         7745 non-null   object
#  10  Description        6938 non-null   object
#  11  Nearby places      7745 non-null   object
#  12  Image              7745 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 786.7+ KB

# %%
levenshtein  = strsimpy.NormalizedLevenshtein()
def levenshtein_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 - levenshtein.distance(x,y)

def difference_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 if x==y else 0

# %%
def clust_filter(arr):
    flag = [False]*len(arr)
    cluster  = []
    for i in range(0,len(arr)-1):
        if (flag[i]==False):
            list_id = []
            for j in range(i + 1, len(arr)):
                if (flag[j]==False):
                    name = levenshtein_score(arr[i][0],arr[j][0])
                    cpu = difference_score(arr[i][2],arr[j][2])
                    ram = difference_score(arr[i][5],arr[j][5])
                    rom = difference_score(arr[i][6],arr[j][6])
                    color = difference_score(arr[i][10],arr[j][10])
                    score = 0.5 * name + 0.05 * cpu + 0.2 * ram + 0.2 * rom + 0.05 * color
                    if (score > 0.95):
                        flag[j] = True
                        list_id.append(j)
            arr[i].append(list_id)
            cluster.append(arr[i])
    return cluster

# %% [markdown]
# ###import recordlinkage

# %%
# !pip install recordlinkage
# !pip install Unidecode

# %%
import recordlinkage
import unidecode

# %%
data_df
# Out:
#           City                                     Hotel name  \
# 0     Hà Nội               Khách sạn HANZ Regal Hotel Hanoi
# 1     Hà Nội  Khách sạn La Nueva Boutique Hotel Hanoi & Spa
# 2     Hà Nội                 Khách sạn La Storia Ruby Hotel
# 3     Hà Nội                      Khách sạn LeaH Silk Hotel
# 4     Hà Nội          Khách sạn Babylon Premium Hotel & Spa
# ...        ...                                            ...
# 7740   Hạ Long                             Khách sạn The Twin
# 7741   Hạ Long                             Khách sạn Sea Star
# 7742   Hạ Long                    Khách Sạn Dragon Hạ Long
# 7743   Hạ Long                             Khách Sạn Sunshine
# 7744   Hạ Long                       Khách sạn Galaxy Hạ Long
#
#                                                     Url  \
# 0     https://www.booking.com/hotel/vn/90-pham-huy-t...
# 1     https://www.booking.com/hotel/vn/hanoi-eleganc...
# 2     https://www.booking.com/hotel/vn/hanoi-eleganc...
# 3     https://www.booking.com/hotel/vn/leah-silk.vi....
# 4     https://www.booking.com/hotel/vn/babylon-premi...
# ...                                                 ...
# 7740  https://mytour.vn/khach-san/44177-khach-san-th...
# 7741  https://mytour.vn/khach-san/39745-khach-san-se...
# 7742  https://mytour.vn/khach-san/53773-khach-san-dr...
# 7743  https://mytour.vn/khach-san/49166-khach-san-su...
# 7744  https://mytour.vn/khach-san/39775-khach-san-ga...
#
#                                                 Address  Stars    Price  \
# 0     90 Pham Huy Thong, Quận Ba Đình, Hà Nội, Viê...    2.0   421890
# 1     32 Lo Su Street, Quận Hoàn Kiếm, Hà Nội, Viê...    4.0  1316000
# 2     3 Yen Thai Street, Quận Hoàn Kiếm, Hà Nội, V...    3.0   625000
# 3     41- 43 Hàng Bông, Hoàn Kiếm , Hà Nội, Quận Hoà...    4.0  1800000
# 4     05-07 Hàng Hòm, Quận Hoàn Kiếm, Hà Nội, Việ...    4.0  1262250
# ...                                                 ...    ...      ...
# 7740  Tt 31-32 , Đường Hạ Long - Sun Premier Village...    4.0  1684766
# 7741  Bt 08 - Khu Villa Sao Biển, Phan Chu Trinh, Th...    3.0   665456
# 7742  8 , Lộc Vừng 2 , Khu Premier Village , Đườn...    3.0   897838
# 7743  56a Tuệ Tĩnh, Khu Đô Thị Hồng Vận, Đường Tuệ T...    2.0   508093
# 7744  15, Tiên Ông, Phường Bãi Cháy, Thành Phố Hạ Lo...    4.0   753251
#
#       Rating  Number of reviews  \
# 0        7.8                 86
# 1        9.3                209
# 2        9.6                217
# 3        9.1                 72
# 4        9.4                627
# ...      ...                ...
# 7740     8.0                  1
# 7741     8.2                  9
# 7742     8.4                  0
# 7743     7.0                  0
# 7744     9.4                  5
#
#                                                 Reviews  \
# 0     ['“máy lạnh mát, wifi trong từng phòng nên mạn...
# 1     ['“Địa điểm tuyệt vời, đi một xíu là ra đến hồ...
# 2     ['“- vị trí gần hồ gươm rất tiện cho việc đi b...
# 3     ['“Mình ở phòng có cửa thông với phòng khác, v...
# 4     ['“Phòng rất rộng và sạch.\nVị trí ngay giữa k...
# ...                                                 ...
# 7740  ['Giải quyết linh động tinh huống cho khách kh...
# 7741  ['Tạm được\nĐi gia đình đúng dịp dịch nên cả n...
# 7742                                                 []
# 7743                                                 []
# 7744  ['Galaxy Hotel Hạ Long\nMình đặt 1 phòng 3 giư...
#
#                                              Facilities  \
# 0     ['Xe đưa đón sân bay', 'Wi-Fi miễn phí', 'P...
# 1     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# 2     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# 3     ['1 hồ bơi', 'Xe đưa đón sân bay', 'Phòng kh...
# 4     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# ...                                                 ...
# 7740  ['Đưa/đón khách sân bay', 'Lễ tân 24h', 'Giữ h...
# 7741  ['American Express', 'Đưa/đón khách sân bay', ...
# 7742  ['Bãi đỗ xe', 'Cho thuê xe máy', 'Giữ hành lý'...
# 7743  ['Lễ tân 24h', 'Giữ hành lý', 'Bán tour', 'Int...
# 7744  ['Đưa/đón khách sân bay', 'Phòng gym', 'Giữ hà...
#
#                                             Description  \
# 0     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 1     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 2     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 3     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 4     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# ...                                                 ...
# 7740  ['Tọa lạc ở thành phố Hạ Long, cách cáp treo N...
# 7741  ['Được nâng cấp vào năm , Khách sạn Sea Stars ...
# 7742  ['Khách Sạn Dragon Hạ Long là nơi cung cấp dị...
# 7743  ['Sunshine Hotel in Móng Cái has 2-star accomm...
# 7744  ['Được UNESCO công nhận là di sản thiên nhiên ...
#
#                                           Nearby places  \
# 0     [('Hồ Ngọc Khánh', '0,3 km'), ('Trung tâm thươ...
# 1     [('Nhà hát múa rối Thăng Long', '0,1 km'), ('Đ...
# 2     [('Quảng Trường Đông Kinh Nghĩa Thục', '0,4 km...
# 3     [('Nhà thờ Thánh Joseph', '0,3 km'), ('Quảng T...
# 4     [('Quảng Trường Đông Kinh Nghĩa Thục', '0,3 km...
# ...                                                 ...
# 7740  [('Nhà hàng Bayview', '369 m'), ('Nhà Hàng Phư...
# 7741  [('Nhà hàng Cua Vàng', '59 m'), ('1900 Coff...
# 7742                                                 []
# 7743  [('Don Chicken Vincom Móng Cái', '930 m'), ('N...
# 7744  [('Nhà Hàng Lâm Hải', '131 m'), ('Mixue Bãi Ch...
#
#                                                   Image
# 0     ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 1     ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 2     ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 3     ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 4     ['https://cf.bstatic.com/xdata/images/hotel/ma...
# ...                                                 ...
# 7740  ['https://img.tripi.vn/cdn-cgi/image/width=124...
# 7741  ['https://img.tripi.vn/cdn-cgi/image/width=124...
# 7742  ['https://img.tripi.vn/cdn-cgi/image/width=124...
# 7743  ['https://img.tripi.vn/cdn-cgi/image/width=124...
# 7744  ['https://img.tripi.vn/cdn-cgi/image/width=840...
#
# [7745 rows x 13 columns]

# %% [markdown]
# ###Hotel-name

# %%
#Bước 1: Chuyển tên KS về dạng chữ thường
data_df['new_name'] = data_df['Hotel name'].str.lower()
data_df['new_name']
# Out:
# 0                    khách sạn hanz regal hotel hanoi
# 1       khách sạn la nueva boutique hotel hanoi & spa
# 2                      khách sạn la storia ruby hotel
# 3                           khách sạn leah silk hotel
# 4               khách sạn babylon premium hotel & spa
#                             ...
# 7740                               khách sạn the twin
# 7741                               khách sạn sea star
# 7742                      khách sạn dragon hạ long
# 7743                               khách sạn sunshine
# 7744                         khách sạn galaxy hạ long
# Name: new_name, Length: 7745, dtype: object

# %%
#Bước 2: Loại bỏ những substring thông dụng: khách sạn, căn hộ,...
subnames = ["căn hộ", "apartment", 
            "khách sạn", "hotel", "hostel", "nhà khách", "nhà thuyền"
            "khu", "nghỉ dưỡng", "nghỉ mát", "resort", "spa",
            "nhà", "nhà dân dịch vụ", "home", "house", "homestay", "serviced homestay",
            "biệt thự", "villa", 
            "du thuyền", "cruise", 
            "gần", "sang trọng", "near", "luxury", "mới", 
            "bungalow", "restaurant", "residences", "studio", "bar", 
            "và", "and", "&"
            ]
data_df['new_name'].replace(subnames,'', inplace=True, regex=True)
data_df['new_name']
# Out:
# 0                 hanz regal  hanoi
# 1        la nueva boutique  hanoi
# 2                   la storia ruby
# 3                        leah silk
# 4                babylon premium
#                    ...
# 7740                       the twin
# 7741                       sea star
# 7742    khách sạn dragon hạ long
# 7743                       sunshine
# 7744                 galaxy hạ long
# Name: new_name, Length: 7745, dtype: object

# %%
#Bước 3: Bỏ dấu
data_df['new_name']=[unidecode.unidecode(y) for y in data_df['new_name']]
data_df['new_name']
# Out:
# 0                 hanz regal  hanoi
# 1        la nueva boutique  hanoi
# 2                   la storia ruby
# 3                        leah silk
# 4                babylon premium
#                    ...
# 7740                       the twin
# 7741                       sea star
# 7742       khach san dragon ha long
# 7743                       sunshine
# 7744                 galaxy ha long
# Name: new_name, Length: 7745, dtype: object

# %%
#Bước 4: Với những tên KS có 2 phần tiếng anh, tiếng việt --> lấy 1 phần
data_df['new_name'] = [y.partition('(')[0] for y in data_df['new_name']]
data_df['new_name']
# Out:
# 0                 hanz regal  hanoi
# 1        la nueva boutique  hanoi
# 2                   la storia ruby
# 3                        leah silk
# 4                babylon premium
#                    ...
# 7740                       the twin
# 7741                       sea star
# 7742       khach san dragon ha long
# 7743                       sunshine
# 7744                 galaxy ha long
# Name: new_name, Length: 7745, dtype: object

# %%
#Bước 5: Loại bỏ khoảng cách giữa các từ
data_df['new_name'].replace(' ','', inplace=True, regex=True)
data_df['new_name']
# Out:
# 0             hanzregalhanoi
# 1       lanuevaboutiquehanoi
# 2               lastoriaruby
# 3                   leahsilk
# 4             babylonpremium
#                 ...
# 7740                 thetwin
# 7741                 seastar
# 7742    khachsandragonhalong
# 7743                sunshine
# 7744            galaxyhalong
# Name: new_name, Length: 7745, dtype: object

# %% [markdown]
# ###Address

# %%
#Bước 1: Chuyển về dạng chữ thường
#Bước 1: Chuyển tên KS về dạng chữ thường
data_df['new_add'] = data_df['Address'].str.lower()
data_df['new_add']
# Out:
# 0       90 pham huy thong, quận ba đình, hà nội, viê...
# 1       32 lo su street, quận hoàn kiếm, hà nội, viê...
# 2       3 yen thai street, quận hoàn kiếm, hà nội, v...
# 3       41- 43 hàng bông, hoàn kiếm , hà nội, quận hoà...
# 4       05-07 hàng hòm, quận hoàn kiếm, hà nội, việ...
#                               ...
# 7740    tt 31-32 , đường hạ long - sun premier village...
# 7741    bt 08 - khu villa sao biển, phan chu trinh, th...
# 7742    8 , lộc vừng 2 , khu premier village , đườn...
# 7743    56a tuệ tĩnh, khu đô thị hồng vận, đường tuệ t...
# 7744    15, tiên ông, phường bãi cháy, thành phố hạ lo...
# Name: new_add, Length: 7745, dtype: object

# %%
#Kiểm tra xem có bản ghi nào chứa "vn" hay không?
m1_df = data_df[data_df['new_add'].str.contains('vn')]
m1_df
# Out:
#            City                                         Hotel name  \
# 3837  Nha Trang                              Căn hộ Căn hộ cao cấp
# 3908   Phú Quốc  Nhà nghỉ B&B Sunny Venice Grand World Phu Quoc...
# 3923   Phú Quốc                 Nhà khách Venice Cafe and Homestay
# 3955   Phú Quốc  Khách sạn HANZ Premium Power Hotel Grand World...
# 4143   Phú Quốc                 Khách sạn Mới Fern Forest Homestay
# 5464     Hà Nội        Khách sạn Ancient Lane (Ancient Lane Hotel)
#
#                                                     Url  \
# 3837  https://www.booking.com/hotel/vn/can-ho-cao-ca...
# 3908  https://www.booking.com/hotel/vn/sunny-venice-...
# 3923  https://www.booking.com/hotel/vn/venice-cafe-a...
# 3955  https://www.booking.com/hotel/vn/hanz-power-mi...
# 4143  https://www.booking.com/hotel/vn/fern-forest-h...
# 5464  https://www.agoda.com/vi-vn/ancient-lane-hotel...
#
#                                                 Address  Stars   Price  \
# 3837   Căn hộ VNC - CT3 Phước Hải, Nha Trang, Việt Nam    0.0  864000
# 3908  Vinpearl VN-22 Grand World Phú Quốc, Ganh Dau,...    3.0  624000
# 3923  Gành Dầu - Cửa Cạn VN-10 Grand World, Ganh Dau...    3.0  700000
# 3955  VN44 Grand World, Bãi Dài, Gành Dầu, Phú Quốc....    0.0  874650
# 4143  Grand World, Gành Dầu, Phú Quốc VN - 03, Ganh ...    0.0  600000
# 5464  Số 2 đường Tam Thương, Phường Hàng Gai, Quận H...   35.0  662338
#
#       Rating  Number of reviews  \
# 3837     0.0                  0
# 3908     8.4                 11
# 3923     7.9                  7
# 3955     8.2                  8
# 4143     0.0                  0
# 5464     9.0               1236
#
#                                                 Reviews  \
# 3837                                                 []
# 3908  ['“Các bạn nv rất nhiệt tình, ra vào chào khác...
# 3923  ['“The location is great, on the balcony, you ...
# 3955  ['“nam tai trung tam grandworld rat dep, di la...
# 4143                                                 []
# 5464  ['địa điểm thì do nằm trong hẻm vì Hà nội đặt ...
#
#                                              Facilities  \
# 3837                                                 []
# 3908  ['Dịch vụ đưa đón sân bay (miễn phí)', 'Chỗ đ...
# 3923  ['Xe đưa đón sân bay', 'Phòng không hút thu...
# 3955  ['Dịch vụ đưa đón sân bay (miễn phí)', 'Phòng...
# 4143  ['Phòng không hút thuốc', 'Giáp biển', 'Chô...
# 5464  ['Cách phương tiện công cộng 950 m', 'Nằm ở tr...
#
#                                             Description  \
# 3837  Căn hộ cao cấp is a property with a private po...
# 3908  Nằm cách Bãi biển Vũng Bầu 2,1 km, Sunny Venic...
# 3923  Chỗ nghỉ này cách bãi biển 12 phút đi bộ. Tọa ...
# 3955  \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 4143  Situated in Phu Quoc, within 2.3 km of Vung Ba...
# 5464                                                NaN
#
#                                           Nearby places  \
# 3837  [('Bến xe Buýt Liên tỉnh', '1,2 km'), ('Nha Th...
# 3908  [('Sòng bạc Corona Casino', '0,7 km'), ('Công ...
# 3923  [('Sòng bạc Corona Casino', '0,6 km'), ('Công ...
# 3955  [('Sòng bạc Corona Casino', '0,8 km'), ('Công ...
# 4143  [('Sòng bạc Corona Casino', '0,8 km'), ('Công ...
# 5464  ['Việt Nam Bảo tàng Lịch sử quân sự - 800 m', ...
#
#                                                   Image  \
# 3837  ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 3908  ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 3923  ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 3955  ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 4143  ['https://cf.bstatic.com/xdata/images/hotel/ma...
# 5464  https://pix6.agoda.net/hotelImages/5100415/-1/...
#
#                                          new_name  \
# 3837                                       caocap
# 3908  nghibbsunnyvenicegrworldphuquocunitedcenter
# 3923                               venicecafestay
# 3955               hanzpremiumpowergrworldphuquoc
# 4143                               fernforeststay
# 5464                                  ancientlane
#
#                                                 new_add
# 3837   căn hộ vnc - ct3 phước hải, nha trang, việt nam
# 3908  vinpearl vn-22 grand world phú quốc, ganh dau,...
# 3923  gành dầu - cửa cạn vn-10 grand world, ganh dau...
# 3955  vn44 grand world, bãi dài, gành dầu, phú quốc....
# 4143  grand world, gành dầu, phú quốc vn - 03, ganh ...
# 5464  số 2 đường tam thương, phường hàng gai, quận h...

# %%
#Bước 2: Loại bỏ mã vùng/mã tỉnh 
data_df['new_add'] = [y.partition(', việt nam')[0] for y in data_df['new_add']]
data_df['new_add']
# Out:
# 0       90 pham huy thong, quận ba đình, hà nội, viê...
# 1       32 lo su street, quận hoàn kiếm, hà nội, viê...
# 2       3 yen thai street, quận hoàn kiếm, hà nội, v...
# 3       41- 43 hàng bông, hoàn kiếm , hà nội, quận hoà...
# 4       05-07 hàng hòm, quận hoàn kiếm, hà nội, việ...
#                               ...
# 7740    tt 31-32 , đường hạ long - sun premier village...
# 7741    bt 08 - khu villa sao biển, phan chu trinh, th...
# 7742    8 , lộc vừng 2 , khu premier village , đườn...
# 7743    56a tuệ tĩnh, khu đô thị hồng vận, đường tuệ t...
# 7744    15, tiên ông, phường bãi cháy, thành phố hạ lo...
# Name: new_add, Length: 7745, dtype: object

# %%
#Bước 3: Loại bỏ các substring thông dụng
subadds = ["xóm", "quận", "thị xã", "ngõ", "số", "tòa", "thành phố", "phố cổ", "phố",  
           "đường", "phường", "cư xá", "cảng", "hẻm", "khu", "đô thị", "nhà",
           "ngách", "phòng", "căn", "tầng", "tỉnh", "tổ", "ap", "ấp", "lô", "bãi",
           "xã", "huyện", "du lịch", "di tích", "đại lộ", "đảo", "và", "tel 02633.608084",
           "trung tâm", "đối diện", "phía", "sau", "trước", "siêu thị", "vn", "quan",
           "no", "no.", "nos", "island", "alley", "lane", "street", "ward", "district",
           "group", "province", "block", "beach", "city", "basilica", "market", "lake",
           "area", "unit", "gate", "port", "wharft", "near by", "building", "zone",
           "tp", "str", "st", "dist", "pro", "bis", "kđt", "hcmc", "hcm", 
           "hà nội", "hồ chí minh", "đà lạt", "đà nẵng", "nha trang", "vũng tàu", 
           "phú quốc", "quảng ninh", "hạ long", "ha long", "ha noi", "ho chi minh",
           "da lat", "da nang", "vung tau", "phu quoc", "quang ninh", "viet nam", "vietnam", 
           ","
            ]

data_df['new_add'].replace(subadds,'', inplace=True, regex=True)
data_df['new_add']
# Out:
# 0           90 pham huy thong  ba đình hà nội việt nam
# 1                 32 lo su   hoàn kiếm hà nội việt nam
# 2               3 yen thai   hoàn kiếm hà nội việt nam
# 3       41- 43 hàng bông hoàn kiếm    hoàn kiếm hà nô...
# 4            05-07 hàng hòm  hoàn kiếm hà nội việt nam
#                               ...
# 7740         tt 31-32    - sun premier village halong
# 7741            bt 08 -  villa sao biển phan chu trinh
# 7742    8  ̣c vừng 2   premier village  đường hạ lo...
# 7743         56a tuệ tĩnh   hồng vận  tuệ tĩnh  móng cái
# 7744                                15 tiên ông   cháy
# Name: new_add, Length: 7745, dtype: object

# %%
# #Bước 4: Bỏ dấu
data_df['new_add']=[unidecode.unidecode(y) for y in data_df['new_add']]
data_df['new_add']
# Out:
# 0              90 pham huy thong  ba dinh ha noi viet nam
# 1                    32 lo su   hoan kiem ha noi viet nam
# 2                  3 yen thai   hoan kiem ha noi viet nam
# 3       41- 43 hang bong hoan kiem    hoan kiem ha noi...
# 4               05-07 hang hom  hoan kiem ha noi viet nam
#                               ...
# 7740         tt 31-32    - sun premier village halong
# 7741            bt 08 -  villa sao bien phan chu trinh
# 7742     8  c vung 2   premier village  duong ha long
# 7743         56a tue tinh   hong van  tue tinh  mong cai
# 7744                                15 tien ong   chay
# Name: new_add, Length: 7745, dtype: object

# %%
#Bước 5: Loại bỏ khoảng cách giữa các từ
data_df['new_add'].replace(' ','', inplace=True, regex=True)
data_df['new_add']
# Out:
# 0                90phamhuythongbadinhhanoivietnam
# 1                      32losuhoankiemhanoivietnam
# 2                    3yenthaihoankiemhanoivietnam
# 3       41-43hangbonghoankiemhoankiemhanoivietnam
# 4                05-07hanghomhoankiemhanoivietnam
#                           ...
# 7740              tt31-32-sunpremiervillagehalong
# 7741                bt08-villasaobienphanchutrinh
# 7742             8cvung2premiervillageduonghalong
# 7743              56atuetinhhongvantuetinhmongcai
# 7744                                15tienongchay
# Name: new_add, Length: 7745, dtype: object

# %% [markdown]
# ###Compare

# %%
compare = recordlinkage.Compare()

# initialise similarity measurement algorithms
compare.string('new_add', 'new_add', method='jarowinkler', threshold=0.85, label='Address')
compare.string('new_name', 'new_name', method='levenshtein', threshold=0.85, label='Hotel_name')
compare.string('City', 'City', method='jarowinkler', threshold=0.85, label='City')

# %%
indexer = recordlinkage.Index()
indexer.block(left_on='City')

# %%
eb_dup=indexer.index(data_df)
eb_ft=compare.compute(eb_dup,data_df)

# %%
eb_matches = eb_ft[eb_ft.sum(axis=1) >=2.5].reset_index()
eb_matches
# Out:
#      level_0  level_1  Address  Hotel_name  City
# 0        296      204      1.0         1.0   1.0
# 1        334      264      1.0         1.0   1.0
# 2        693      138      1.0         1.0   1.0
# 3        756      712      1.0         1.0   1.0
# 4        794      455      1.0         1.0   1.0
# ..       ...      ...      ...         ...   ...
# 780     6931     5399      1.0         1.0   1.0
# 781     6934     5749      1.0         1.0   1.0
# 782     6937     5396      1.0         1.0   1.0
# 783     7727     6677      1.0         1.0   1.0
# 784     7737     6674      1.0         1.0   1.0
#
# [785 rows x 5 columns]

# %%
data_df.loc[2478]
# Out:
# City                                                            Đà Lạt
# Hotel name                                Khách sạn Lacami Dalat Hotel
# Url                  https://www.booking.com/hotel/vn/lacami-dalat....
# Address              36/6 Lê Văn Tám, Phường 2, thành phố Đà Lạt, L...
# Stars                                                              2.0
# Price                                                           460000
# Rating                                                             7.8
# Number of reviews                                                   11
# Reviews                                                             []
# Facilities           ['Xe đưa đón sân bay', 'Phòng không hút thu...
# Description          Tọa lạc tại thành phố Đà Lạt, cách Công viên Y...
# Nearby places        [('Chùa Tàu Thiên Vương Cổ Sát', '0,4 km'), ('...
# Image                ['https://cf.bstatic.com/xdata/images/hotel/ma...
# new_name                                                   lacamidalat
# new_add                                    36/6levantam2lamdongvietnam
# Name: 2478, dtype: object

# %%
data_df.loc[6062]
# Out:
# City                                                            Đà Lạt
# Hotel name                                          Lacami Dalat Hotel
# Url                  https://www.traveloka.com/vi-vn/hotel/vietnam/...
# Address              36/6 Lê Văn Tám, phường 10, Đà Lạt, Tỉnh Lâm Đ...
# Stars                                                              2.0
# Price                                                           400000
# Rating                                                             8.6
# Number of reviews                                                   62
# Reviews              ['Trải nghiệm rất là tồi tệ. - Dầu gội không c...
# Facilities             ['Nhà hàng', 'Chỗ đậu xe', 'Thang máy', 'WiFi']
# Description          Giờ nhận và trả phòng\r\nGiờ nhận phòng: 14:00...
# Nearby places        [('Big C Dalat', '1.21 km'), ('Hồ Xuân Hương',...
# Image                ['https://ik.imagekit.io/tvlk/apr-asset/dgXfoy...
# new_name                                                   lacamidalat
# new_add                                          36/6levantam10lamdong
# Name: 6062, dtype: object

# %%
len(eb_dup)
# Out:
# 3204072

# %%
eb_ft.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0        785
# 2.0      27635
# 1.0    3175652
# dtype: int64

# %%
eb_matches = eb_ft[eb_ft['Hotel_name'].values*6+ eb_ft['Address'].values*3+eb_ft['City'].values >=9.2 ].reset_index()

# %%
match=eb_matches['level_0'].unique()
num=len(match)
tick=[1]*max(eb_matches['level_0'].max(),eb_matches['level_1'].max())+[1]
ls=[]
for i in match:
    #if tick[i]:
        
        a=set()
        
        b=set()
        b.add(i)
        while b:
            val=b.pop()
            if tick[val]:
                a.add(val)
                tick[val]=0
                x=eb_matches.loc[eb_matches['level_0']==val,'level_1'].to_list()
                x=x+eb_matches.loc[eb_matches['level_1']==val,'level_0'].to_list()
                for j in x:
                    if j:
                        b.add(j)
                        a.add(j)
        if a:
            ls.append(a)

# %%
for i in ls:
    print(i)
# Out:
# {296, 204}
# {264, 334}
# {138, 693}
# {712, 756}
# {794, 455}
# {816, 743}
# {914, 837, 783}
# {602, 892}
# {882, 907, 893}
# {881, 898, 926, 903}
# {901, 70}
# {736, 932}
# {966, 943}
# {843, 967}
# {959, 983}
# {987, 852, 989}
# {216, 304, 988}
# {1086, 1063}
# {1265, 1178}
# {1753, 1638, 1326, 1327}
# {1412, 1109}
# {1200, 1462}
# {1489, 1374}
# {1181, 1783}
# {1176, 1881, 1796}
# {1864, 1261}
# {1755, 1895}
# {1678, 1918}
# {1218, 1919}
# {1945, 1683}
# {2520, 2043}
# {2525, 2511}
# {2547, 2255}
# {5606, 2327}
# {5058, 6954}
# {6955, 5052}
# {5089, 6956}
# {6958, 5047}
# {6962, 5119}
# {5116, 6965}
# {6968, 5065}
# {6969, 5063}
# {6970, 5068}
# {5056, 6971}
# {5112, 6972}
# {5070, 6974}
# {5077, 6975}
# {6977, 5078}
# {6978, 5051}
# {5050, 6980}
# {6986, 5156}
# {5947, 6990}
# {5866, 6991}
# {6994, 5918}
# {5802, 6997}
# {7011, 5894}
# {7017, 5793}
# {5161, 7020}
# {5816, 7029}
# {5097, 7030}
# {7032, 5091}
# {7035, 5878}
# {5822, 7038}
# {7048, 7049}
# {5053, 7055}
# {5209, 7066}
# {5898, 7068}
# {5107, 7069}
# {5784, 7070}
# {7072, 5226}
# {5840, 7074}
# {5884, 7078}
# {5770, 7079}
# {7090, 5126}
# {7091, 5830}
# {5136, 7093}
# {7098, 5103}
# {5853, 7103}
# {7106, 5927}
# {7107, 5774}
# {7108, 5814}
# {5768, 7110}
# {5876, 7111}
# {7113, 5817}
# {5810, 7114}
# {5087, 7119}
# {7082, 7123, 7166}
# {7129, 5246}
# {5915, 7135}
# {7138, 5806}
# {5863, 7143}
# {5800, 7145}
# {5837, 7149}
# {5259, 7151}
# {7152, 5195}
# {7161, 5133}
# {7165, 5862}
# {5211, 7167}
# {5873, 7171}
# {7172, 5110}
# {5313, 5652, 6871}
# {5298, 5658, 6738}
# {5665, 5322, 6821}
# {5402, 5676}
# {5720, 5401}
# {5725, 5423}
# {5374, 5734}
# {5422, 5742}
# {5335, 5743}
# {5753, 6731, 5388}
# {5304, 6715}
# {6716, 5295}
# {5746, 6718}
# {6723, 5292}
# {5306, 6725}
# {6728, 5755}
# {6729, 5286}
# {5329, 6733}
# {6746, 5378}
# {5369, 6750}
# {6752, 5662}
# {6761, 5737}
# {5370, 6775}
# {6776, 5450}
# {6779, 5318}
# {5704, 6790}
# {5433, 6791}
# {6800, 5332}
# {6804, 5391}
# {6805, 5439}
# {6809, 5677}
# {6824, 5685}
# {6825, 5419}
# {6826, 5357}
# {5669, 6829}
# {6836, 5445}
# {6864, 6842}
# {5425, 6874}
# {6875, 5420}
# {6876, 5663}
# {6885, 5670}
# {5324, 6894}
# {6904, 5338}
# {5381, 6911}
# {6916, 5701}
# {6920, 5698}
# {5317, 6927}
# {6931, 5399}
# {5749, 6934}
# {6937, 5396}
# {6677, 7727}
# {7737, 6674}

# %%
for iter in ls:
    min_prince = 999999999999999999999999999999
    min_id = -1
    for id in iter:
        if data_df.loc[id]["Price"] < min_prince:
            min_id = id
            min_prince = data_df.loc[id]["Price"]
    for id in iter:
        if id != min_id:
            data_df = data_df.drop([id])
            print(id)
# Out:
# 204
# 334
# 693
# 756
# 455
# 743
# 914
# 837
# 892
# 907
# 893
# 898
# 926
# 903
# 70
# 932
# 966
# 967
# 959
# 852
# 989
# 304
# 988
# 1086
# 1178
# 1753
# 1638
# 1326
# 1412
# 1462
# 1489
# 1181
# 1176
# 1881
# 1261
# 1895
# 1678
# 1919
# 1945
# 2043
# 2511
# 2547
# 5737
# 6775
# 5450
# 6779
# 6790
# 6791
# 6800
# 6804
# 6805
# 6809
# 5685
# 6825
# 6826
# 5669
# 6836
# 6864
# 6874
# 6875
# 5663
# 5670
# 5324
# 6904
# 6911
# 5701
# 5698
# 6927
# 6931
# 5749
# 6937
# 6677
# 7737

# %%
ls[0]
# Out:
# {204, 296}

# %%
data_df.loc[7288]
# Out:
# City                                                            Đà Lạt
# Hotel name                                     Khách sạn Lacami Đà Lạt
# Url                  https://mytour.vn/khach-san/29603-khach-san-la...
# Address              36/6 Lê Văn Tám, Phường 10, Lê Văn Tám, Thành ...
# Stars                                                              2.0
# Price                                                           448088
# Rating                                                             9.0
# Number of reviews                                                   71
# Reviews              ['Phòng tiện nghi đầy đủ\nLà nơi Tôi chọn để n...
# Facilities           ['Bãi đỗ xe', 'Cho thuê xe máy', 'Đưa/đón khác...
# Description          ['Với vẻ đẹp sang trọng và ấm cúng cùng nội th...
# Nearby places        [('Cây Đa Quán 2', '294 m'), ('Sitooterie - Co...
# Image                ['https://img.tripi.vn/cdn-cgi/image/width=840...
# new_name                                                   lacamidalat
# new_add                                  36/6levantam10levantamlamdong
# Name: 7288, dtype: object

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7061 entries, 0 to 7744
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7061 non-null   object
#  1   Hotel name         7061 non-null   object
#  2   Url                7061 non-null   object
#  3   Address            7061 non-null   object
#  4   Stars              7061 non-null   float64
#  5   Price              7061 non-null   int64
#  6   Rating             7061 non-null   float64
#  7   Number of reviews  7061 non-null   int64
#  8   Reviews            7061 non-null   object
#  9   Facilities         7061 non-null   object
#  10  Description        6294 non-null   object
#  11  Nearby places      7061 non-null   object
#  12  Image              7061 non-null   object
#  13  new_name           7061 non-null   object
#  14  new_add            7061 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 882.6+ KB

# %%
data_df
# Out:
#           City                                     Hotel name  \
# 0     Hà Nội               Khách sạn HANZ Regal Hotel Hanoi
# 1     Hà Nội  Khách sạn La Nueva Boutique Hotel Hanoi & Spa
# 2     Hà Nội                 Khách sạn La Storia Ruby Hotel
# 3     Hà Nội                      Khách sạn LeaH Silk Hotel
# 4     Hà Nội          Khách sạn Babylon Premium Hotel & Spa
# ...        ...                                            ...
# 7740   Hạ Long                             Khách sạn The Twin
# 7741   Hạ Long                             Khách sạn Sea Star
# 7742   Hạ Long                    Khách Sạn Dragon Hạ Long
# 7743   Hạ Long                             Khách Sạn Sunshine
# 7744   Hạ Long                       Khách sạn Galaxy Hạ Long
#
#                                                     Url  \
# 0     https://www.booking.com/hotel/vn/90-pham-huy-t...
# 1     https://www.booking.com/hotel/vn/hanoi-eleganc...
# 2     https://www.booking.com/hotel/vn/hanoi-eleganc...
# 3     https://www.booking.com/hotel/vn/leah-silk.vi....
# 4     https://www.booking.com/hotel/vn/babylon-premi...
# ...                                                 ...
# 7740  https://mytour.vn/khach-san/44177-khach-san-th...
# 7741  https://mytour.vn/khach-san/39745-khach-san-se...
# 7742  https://mytour.vn/khach-san/53773-khach-san-dr...
# 7743  https://mytour.vn/khach-san/49166-khach-san-su...
# 7744  https://mytour.vn/khach-san/39775-khach-san-ga...
#
#                                                 Address  Stars    Price  \
# 0     90 Pham Huy Thong, Quận Ba Đình, Hà Nội, Viê...    2.0   421890
# 1     32 Lo Su Street, Quận Hoàn Kiếm, Hà Nội, Viê...    4.0  1316000
# 2     3 Yen Thai Street, Quận Hoàn Kiếm, Hà Nội, V...    3.0   625000
# 3     41- 43 Hàng Bông, Hoàn Kiếm , Hà Nội, Quận Hoà...    4.0  1800000
# 4     05-07 Hàng Hòm, Quận Hoàn Kiếm, Hà Nội, Việ...    4.0  1262250
# ...                                                 ...    ...      ...
# 7740  Tt 31-32 , Đường Hạ Long - Sun Premier Village...    4.0  1684766
# 7741  Bt 08 - Khu Villa Sao Biển, Phan Chu Trinh, Th...    3.0   665456
# 7742  8 , Lộc Vừng 2 , Khu Premier Village , Đườn...    3.0   897838
# 7743  56a Tuệ Tĩnh, Khu Đô Thị Hồng Vận, Đường Tuệ T...    2.0   508093
# 7744  15, Tiên Ông, Phường Bãi Cháy, Thành Phố Hạ Lo...    4.0   753251
#
#       Rating  Number of reviews  \
# 0        7.8                 86
# 1        9.3                209
# 2        9.6                217
# 3        9.1                 72
# 4        9.4                627
# ...      ...                ...
# 7740     8.0                  1
# 7741     8.2                  9
# 7742     8.4                  0
# 7743     7.0                  0
# 7744     9.4                  5
#
#                                                 Reviews  \
# 0     ['“máy lạnh mát, wifi trong từng phòng nên mạn...
# 1     ['“Địa điểm tuyệt vời, đi một xíu là ra đến hồ...
# 2     ['“- vị trí gần hồ gươm rất tiện cho việc đi b...
# 3     ['“Mình ở phòng có cửa thông với phòng khác, v...
# 4     ['“Phòng rất rộng và sạch.\nVị trí ngay giữa k...
# ...                                                 ...
# 7740  ['Giải quyết linh động tinh huống cho khách kh...
# 7741  ['Tạm được\nĐi gia đình đúng dịp dịch nên cả n...
# 7742                                                 []
# 7743                                                 []
# 7744  ['Galaxy Hotel Hạ Long\nMình đặt 1 phòng 3 giư...
#
#                                              Facilities  \
# 0     ['Xe đưa đón sân bay', 'Wi-Fi miễn phí', 'P...
# 1     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# 2     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# 3     ['1 hồ bơi', 'Xe đưa đón sân bay', 'Phòng kh...
# 4     ['Xe đưa đón sân bay', 'Phòng không hút thu...
# ...                                                 ...
# 7740  ['Đưa/đón khách sân bay', 'Lễ tân 24h', 'Giữ h...
# 7741  ['American Express', 'Đưa/đón khách sân bay', ...
# 7742  ['Bãi đỗ xe', 'Cho thuê xe máy', 'Giữ hành lý'...
# 7743  ['Lễ tân 24h', 'Giữ hành lý', 'Bán tour', 'Int...
# 7744  ['Đưa/đón khách sân bay', 'Phòng gym', 'Giữ hà...
#
#                                             Description  \
# 0     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 1     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 2     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 3     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# 4     \r\nBạn đủ điều kiện nhận giảm giá Genius tại ...
# ...                                                 ...
# 7740  ['Tọa lạc ở thành phố Hạ Long, cách cáp treo N...
# 7741  ['Được nâng cấp vào năm , Khách sạn Sea Stars ...
# 7742  ['Khách Sạn Dragon Hạ Long là nơi cung cấp dị...
# 7743  ['Sunshine Hotel in Móng Cái has 2-star accomm...
# 7744  ['Được UNESCO công nhận là di sản thiên nhiên ...
#
#                                           Nearby places  \
# 0     [('Hồ Ngọc Khánh', '0,3 km'), ('Trung tâm thươ...
# 1     [('Nhà hát múa rối Thăng Long', '0,1 km'), ('Đ...
# 2     [('Quảng Trường Đông Kinh Nghĩa Thục', '0,4 km...
# 3     [('Nhà thờ Thánh Joseph', '0,3 km'), ('Quảng T...
# 4     [('Quảng Trường Đông Kinh Nghĩa Thục', '0,3 km...
# ...                                                 ...
# 7740  [('Nhà hàng Bayview', '369 m'), ('Nhà Hàng Phư...
# 7741  [('Nhà hàng Cua Vàng', '59 m'), ('1900 Coff...
# 7742                                                 []
# 7743  [('Don Chicken Vincom Móng Cái', '930 m'), ('N...
# 7744  [('Nhà Hàng Lâm Hải', '131 m'), ('Mixue Bãi Ch...
#
#                                                   Image              new_name  \
# 0     ['https://cf.bstatic.com/xdata/images/hotel/ma...        hanzregalhanoi
# 1     ['https://cf.bstatic.com/xdata/images/hotel/ma...  lanuevaboutiquehanoi
# 2     ['https://cf.bstatic.com/xdata/images/hotel/ma...          lastoriaruby
# 3     ['https://cf.bstatic.com/xdata/images/hotel/ma...              leahsilk
# 4     ['https://cf.bstatic.com/xdata/images/hotel/ma...        babylonpremium
# ...                                                 ...                   ...
# 7740  ['https://img.tripi.vn/cdn-cgi/image/width=124...               thetwin
# 7741  ['https://img.tripi.vn/cdn-cgi/image/width=124...               seastar
# 7742  ['https://img.tripi.vn/cdn-cgi/image/width=124...  khachsandragonhalong
# 7743  ['https://img.tripi.vn/cdn-cgi/image/width=124...              sunshine
# 7744  ['https://img.tripi.vn/cdn-cgi/image/width=840...          galaxyhalong
#
#                                         new_add
# 0              90phamhuythongbadinhhanoivietnam
# 1                    32losuhoankiemhanoivietnam
# 2                  3yenthaihoankiemhanoivietnam
# 3     41-43hangbonghoankiemhoankiemhanoivietnam
# 4              05-07hanghomhoankiemhanoivietnam
# ...                                         ...
# 7740            tt31-32-sunpremiervillagehalong
# 7741              bt08-villasaobienphanchutrinh
# 7742           8cvung2premiervillageduonghalong
# 7743            56atuetinhhongvantuetinhmongcai
# 7744                              15tienongchay
#
# [7061 rows x 15 columns]

# %%
data_df.to_csv('data_maped.csv', index=False, encoding='utf8')

# %%
data_maped = pd.read_csv("data_maped.csv")

# %%
data_maped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7061 entries, 0 to 7060
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7061 non-null   object
#  1   Hotel name         7061 non-null   object
#  2   Url                7061 non-null   object
#  3   Address            7061 non-null   object
#  4   Stars              7061 non-null   float64
#  5   Price              7061 non-null   int64
#  6   Rating             7061 non-null   float64
#  7   Number of reviews  7061 non-null   int64
#  8   Reviews            7061 non-null   object
#  9   Facilities         7061 non-null   object
#  10  Description        6294 non-null   object
#  11  Nearby places      7061 non-null   object
#  12  Image              7061 non-null   object
#  13  new_name           7055 non-null   object
#  14  new_add            7058 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 827.6+ KB
